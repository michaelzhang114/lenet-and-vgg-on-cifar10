# %%
import argparse
import os, sys
import time
import datetime
import random

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm

import matplotlib.pyplot as plt

# You cannot change this line.
from tools.dataloader import CIFAR10

# %%
# Create the neural network module: VGG16
class Vgg16(nn.Module):
    def __init__(self):
        super(Vgg16, self).__init__()
#         self.conv1 = nn.Conv2d(3,64,3) #(in, out, kernel)
#         self.conv2 = nn.Conv2d(64,64,3)
#         self.pool1 = nn.MaxPool2d(2,2) #(kernel, stride)
#         self.conv3 = nn.Conv2d(64,128,3)
#         self.conv4 = nn.Conv2d(128,128,3)
#         self.pool2 = nn.MaxPool2d(2,2)
#         self.conv5 = nn.Conv2d(128,256,3)
#         self.conv6 = nn.Conv2d(256,256,3)
#         self.fc1 = nn.Linear(1 * 1 * 256, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, 10)
        
        
        self.conv1 = nn.Conv2d(3,64,3) #(in, out, kernel)
        self.conv2 = nn.Conv2d(64,64,3)
        self.pool1 = nn.MaxPool2d(2,2) #(kernel, stride)
        self.conv3 = nn.Conv2d(64,128,3)
        self.pool2 = nn.MaxPool2d(2,2)
        self.conv4 = nn.Conv2d(128,256,3)
        self.pool3 = nn.MaxPool2d(2,2)
        self.fc1 = nn.Linear(2 * 2 * 256, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.pool1(x)
        
        x = F.relu(self.conv3(x))
        
        x = self.pool2(x)
        x = F.relu(self.conv4(x))
        x = self.pool3(x)

        
        #x = F.relu(self.conv6(x))
        
        
        #x = F.relu(self.fc1(x.view(-1, 1 * 1 * 256)))
        x = F.relu(self.fc1(x.view(-1, 2 * 2 * 256)))
        
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x

# %%
# Print some parameters for checking

device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = Vgg16()
net = net.to(device)
testArray = torch.zeros([128,3,32,32])
x = testArray.to(device)
y = net(x)
for name, p in net.named_parameters():
    print(name, p.shape)
# Out:
# conv1.weight torch.Size([64, 3, 3, 3])
# conv1.bias torch.Size([64])
# conv2.weight torch.Size([64, 64, 3, 3])
# conv2.bias torch.Size([64])
# conv3.weight torch.Size([128, 64, 3, 3])
# conv3.bias torch.Size([128])
# conv4.weight torch.Size([256, 128, 3, 3])
# conv4.bias torch.Size([256])
# fc1.weight torch.Size([120, 1024])
# fc1.bias torch.Size([120])
# fc2.weight torch.Size([84, 120])
# fc2.bias torch.Size([84])
# fc3.weight torch.Size([10, 84])
# fc3.bias torch.Size([10])

# %%
# Setting some hyperparameters

TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4
EPOCHS = 300
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model_vgg"

# %%
# Preprocessing

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop([32, 32], padding=2),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))
])

# %%
# Call the dataset Loader
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=1)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=1)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# net = Vgg16()
# net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = False
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model_vgg/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Successfully loaded checkpoint: ./saved_model_vgg/model.h5
# Starting from epoch 187
# Starting from learning rate 0.015277:

# %%
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
# Create helper variables for graphing
val_losses = []
train_losses = []
validation_accuracies = []
epochs = []

# %%
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
    #print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        # Printing initial loss 
        if i == 0 and batch_idx == 0:
            print("initial loss: ",  loss)
        
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        # Calculate accuracy
        total_examples += inputs.size(0)
        correct_examples += torch.eq(targets, predicted).sum().item()

        train_loss += loss

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    
    train_losses.append(avg_loss)

    
    #print(datetime.datetime.now())
    # Validate on the validation dataset
    #print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            # Calculate accuracy
            total_examples += inputs.size(0)
            correct_examples += torch.eq(targets, predicted).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # For graphing
    val_losses.append(avg_loss)
    epochs.append(i)
    validation_accuracies.append(avg_acc)
    
        
    """
    Assignment 4(b)
    Learning rate is an important hyperparameter to tune. Specify a 
    learning rate decay policy and apply it in your training process. 
    Briefly describe its impact on the learning curveduring your 
    training process.    
    Reference learning rate schedule: 
    decay 0.98 for every 2 epochs. You may tune this parameter but 
    minimal gain will be achieved.
    Assignment 4(c)
    As we can see from above, hyperparameter optimization is critical 
    to obtain a good performance of DNN models. Try to fine-tune the 
    model to over 70% accuracy. You may also increase the number of 
    epochs to up to 100 during the process. Briefly describe what you 
    have tried to improve the performance of the LeNet-5 model.
    """
    DECAY_EPOCHS = 2
    DECAY = 0.98
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate *= DECAY
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# Epoch 187:
# 352
# Training loss: 0.8720, Training accuracy: 0.7232
# Validation loss: 0.9932, Validation accuracy: 0.6838
# Saving ...
# Epoch 188:
# 352
# Training loss: 1.0211, Training accuracy: 0.6830
# Validation loss: 1.3542, Validation accuracy: 0.6126
# Current learning rate has decayed to 0.014971
# Epoch 189:
# 352
# Training loss: 0.6296, Training accuracy: 0.8055
# Validation loss: 0.6230, Validation accuracy: 0.8092
# Saving ...
# Epoch 190:
# 352
# Training loss: 0.4719, Training accuracy: 0.8494
# Validation loss: 0.5652, Validation accuracy: 0.8256
# Current learning rate has decayed to 0.014672
# Saving ...
# Epoch 191:
# 352
# Training loss: 0.4084, Training accuracy: 0.8681
# Validation loss: 0.5501, Validation accuracy: 0.8390
# Saving ...
# Epoch 192:
# 352
# Training loss: 0.3662, Training accuracy: 0.8788
# Validation loss: 0.5433, Validation accuracy: 0.8400
# Current learning rate has decayed to 0.014378
# Saving ...
# Epoch 193:
# 352
# Training loss: 0.3356, Training accuracy: 0.8915
# Validation loss: 0.5192, Validation accuracy: 0.8466
# Saving ...
# Epoch 194:
# 352
# Training loss: 0.3023, Training accuracy: 0.8996
# Validation loss: 0.5224, Validation accuracy: 0.8502
# Current learning rate has decayed to 0.014091
# Saving ...
# Epoch 195:
# 352
# Training loss: 0.2767, Training accuracy: 0.9075
# Validation loss: 0.5238, Validation accuracy: 0.8522
# Saving ...
# Epoch 196:
# 352
# Training loss: 0.2570, Training accuracy: 0.9144
# Validation loss: 0.5156, Validation accuracy: 0.8538
# Current learning rate has decayed to 0.013809
# Saving ...
# Epoch 197:
# 352
# Training loss: 0.2395, Training accuracy: 0.9208
# Validation loss: 0.5120, Validation accuracy: 0.8566
# Saving ...
# Epoch 198:
# 352
# Training loss: 0.2191, Training accuracy: 0.9249
# Validation loss: 0.5121, Validation accuracy: 0.8614
# Current learning rate has decayed to 0.013533
# Saving ...
# Epoch 199:
# 352
# Training loss: 0.2094, Training accuracy: 0.9295
# Validation loss: 0.5019, Validation accuracy: 0.8608
# Epoch 200:
# 352
# Training loss: 0.1966, Training accuracy: 0.9328
# Validation loss: 0.4988, Validation accuracy: 0.8632
# Current learning rate has decayed to 0.013262
# Saving ...
# Epoch 201:
# 352
# Training loss: 0.1810, Training accuracy: 0.9372
# Validation loss: 0.5083, Validation accuracy: 0.8666
# Saving ...
# Epoch 202:
# 352
# Training loss: 0.1747, Training accuracy: 0.9413
# Validation loss: 0.5108, Validation accuracy: 0.8662
# Current learning rate has decayed to 0.012997
# Epoch 203:
# 352
# Training loss: 0.1599, Training accuracy: 0.9444
# Validation loss: 0.5207, Validation accuracy: 0.8604
# Epoch 204:
# 352
# Training loss: 0.1600, Training accuracy: 0.9457
# Validation loss: 0.5472, Validation accuracy: 0.8618
# Current learning rate has decayed to 0.012737
# Epoch 205:
# 352
# Training loss: 0.1479, Training accuracy: 0.9481
# Validation loss: 0.5331, Validation accuracy: 0.8696
# Saving ...
# Epoch 206:
# 352
# Training loss: 0.1418, Training accuracy: 0.9494
# Validation loss: 0.5441, Validation accuracy: 0.8662
# Current learning rate has decayed to 0.012482
# Epoch 207:
# 352
# Training loss: 0.1330, Training accuracy: 0.9540
# Validation loss: 0.5409, Validation accuracy: 0.8612
# Epoch 208:
# 352
# Training loss: 0.1317, Training accuracy: 0.9557
# Validation loss: 0.5449, Validation accuracy: 0.8636
# Current learning rate has decayed to 0.012232
# Epoch 209:
# 352
# Training loss: 0.1197, Training accuracy: 0.9578
# Validation loss: 0.5389, Validation accuracy: 0.8724
# Saving ...
# Epoch 210:
# 352
# Training loss: 0.1176, Training accuracy: 0.9598
# Validation loss: 0.5542, Validation accuracy: 0.8658
# Current learning rate has decayed to 0.011988
# Epoch 211:
# 352
# Training loss: 0.1180, Training accuracy: 0.9605
# Validation loss: 0.5702, Validation accuracy: 0.8680
# Epoch 212:
# 352
# Training loss: 0.1116, Training accuracy: 0.9625
# Validation loss: 0.5966, Validation accuracy: 0.8644
# Current learning rate has decayed to 0.011748
# Epoch 213:
# 352
# Training loss: 0.1068, Training accuracy: 0.9637
# Validation loss: 0.5787, Validation accuracy: 0.8668
# Epoch 214:
# 352
# Training loss: 0.0988, Training accuracy: 0.9659
# Validation loss: 0.5911, Validation accuracy: 0.8674
# Current learning rate has decayed to 0.011513
# Epoch 215:
# 352
# Training loss: 0.0957, Training accuracy: 0.9670
# Validation loss: 0.5848, Validation accuracy: 0.8660
# Epoch 216:
# 352
# Training loss: 0.0942, Training accuracy: 0.9682
# Validation loss: 0.5888, Validation accuracy: 0.8700
# Current learning rate has decayed to 0.011283
# Epoch 217:
# 352
# Training loss: 0.0903, Training accuracy: 0.9688
# Validation loss: 0.6009, Validation accuracy: 0.8618
# Epoch 218:
# 352
# Training loss: 0.0874, Training accuracy: 0.9692
# Validation loss: 0.5780, Validation accuracy: 0.8718
# Current learning rate has decayed to 0.011057
# Epoch 219:
# 352
# Training loss: 0.0867, Training accuracy: 0.9708
# Validation loss: 0.5901, Validation accuracy: 0.8676
# Epoch 220:
# 352
# Training loss: 0.0816, Training accuracy: 0.9719
# Validation loss: 0.6158, Validation accuracy: 0.8708
# Current learning rate has decayed to 0.010836
# Epoch 221:
# 352
# Training loss: 0.0759, Training accuracy: 0.9732
# Validation loss: 0.6479, Validation accuracy: 0.8654
# Epoch 222:
# 352
# Training loss: 0.0786, Training accuracy: 0.9734
# Validation loss: 0.5851, Validation accuracy: 0.8698
# Current learning rate has decayed to 0.010619
# Epoch 223:
# 352
# Training loss: 0.0722, Training accuracy: 0.9751
# Validation loss: 0.6158, Validation accuracy: 0.8658
# Epoch 224:
# 352
# Training loss: 0.0729, Training accuracy: 0.9753
# Validation loss: 0.6304, Validation accuracy: 0.8672
# Current learning rate has decayed to 0.010407
# Epoch 225:
# 352
# Training loss: 0.0669, Training accuracy: 0.9768
# Validation loss: 0.6197, Validation accuracy: 0.8682
# Epoch 226:
# 352
# Training loss: 0.0669, Training accuracy: 0.9767
# Validation loss: 0.6361, Validation accuracy: 0.8714
# Current learning rate has decayed to 0.010199
# Epoch 227:
# 352
# Training loss: 0.0662, Training accuracy: 0.9778
# Validation loss: 0.6252, Validation accuracy: 0.8678
# Epoch 228:
# 352
# Training loss: 0.0658, Training accuracy: 0.9777
# Validation loss: 0.6406, Validation accuracy: 0.8696
# Current learning rate has decayed to 0.009995
# Epoch 229:
# 352
# Training loss: 0.0579, Training accuracy: 0.9805
# Validation loss: 0.6633, Validation accuracy: 0.8666
# Epoch 230:
# 352
# Training loss: 0.0574, Training accuracy: 0.9798
# Validation loss: 0.6234, Validation accuracy: 0.8706
# Current learning rate has decayed to 0.009795
# Epoch 231:
# 352

# %%
# Plot
tmp = []
for i in val_losses:
    tmp.append(i)
val_losses = tmp

tmp = []
for i in train_losses:
    tmp.append(i)
train_losses = tmp

epochs = []
for i in range(len(val_losses)):
    epochs.append(i)

    
val, idx = max((val, idx) for (idx, val) in enumerate(validation_accuracies))
print("Max validation acc:", val, " at Epoch: ", idx)
    
#plt.plot(epochs, val_losses, label="val_losses") 
plt.plot(epochs, train_losses, label="train_losses") 
plt.legend()
plt.xlabel('Epochs') 
plt.ylabel('Loss') 
plt.title('Loss curve')
plt.show()

# %%
from tools.testloader import TEST_SET
import numpy as np


testset = TEST_SET(root=DATAROOT, train=False, transform=transform_train)
testloader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=False, num_workers=1)

results = []

with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):
        # Copy inputs to device         
        inputs = inputs.to(device)
        
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output from the DNN.
        outputs = net(inputs)
        
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        
        predicted_np = predicted.data.cpu().numpy()
        for i in predicted_np:
            results.append(i)
# len(results)

# %%
header = ["Id", "Category"]

out_to_file = []

out_to_file.append(header)

for i in range(len(results)):
    tmp = [i, results[i]]
    out_to_file.append(tmp)

#print(out_to_file)

np_out = np.array(out_to_file)

np.savetxt('output.csv', np_out, fmt='%s', delimiter=",")
